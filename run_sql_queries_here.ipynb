# %%
import duckdb
import pandas as pd

# %%
sql_query = '''
show tables
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []
