# %%
import duckdb
import pandas as pd

# %%
sql_query = '''
select * from parking_violations_2023
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#        summons_number registration_state plate_type issue_date  \
# 0          9010912681                 CA        PAS 2022-10-11
# 1          4858762841                 NY        PAS 2023-08-21
# 2          4854645684                 FL        PAS 2023-07-26
# 3          9044582707                 NY        PAS 2023-04-10
# 4          9041503330                 NY        PAS 2023-03-21
# ...               ...                ...        ...        ...
# 99995      9069356715                 NY        COM 2023-08-07
# 99996      4802425399                 NY        OMS 2022-09-25
# 99997      4809109689                 NY        ORG 2022-10-28
# 99998      4834558370                 NY        PAS 2023-04-04
# 99999      4837284462                 NY        PAS 2023-04-21
#
#        violation_code vehicle_body_type vehicle_make issuing_agency  \
# 0                  17              SUBN         FORD              T
# 1                  36              4DSD        HONDA              V
# 2                  36                UT          BMW              V
# 3                  21              SUBN        SUBAR              T
# 4                  21              4DSD        CHEVR              T
# ...               ...               ...          ...            ...
# 99995              21               VAN         FORD              T
# 99996              36              SUBN        CHEVR              V
# 99997              36              SUBN        NISSA              V
# 99998              36              4DSD        LEXUS              V
# 99999              36              4DSD          KIA              V
#
#        vehicle_expiration_date  violation_location  ...  from_hours_in_effect  \
# 0                     20220788                  50  ...                 0700A
# 1                            0                <NA>  ...                  None
# 2                            0                <NA>  ...                  None
# 3                     20231217                  79  ...                 0900A
# 4                     20250320                  26  ...                 1100A
# ...                        ...                 ...  ...                   ...
# 99995                 20240831                  30  ...                 1100A
# 99996                        0                <NA>  ...                  None
# 99997                        0                <NA>  ...                  None
# 99998                        0                <NA>  ...                  None
# 99999                        0                <NA>  ...                  None
#
#        to_hours_in_effect  vehicle_color unregistered_vehicle vehicle_year  \
# 0                   0400P          BLACK                 <NA>            0
# 1                    None             GY                 <NA>         2003
# 2                    None            WHI                 <NA>         2022
# 3                   1030A             GY                 <NA>         2017
# 4                   1230A             BK                 <NA>         2018
# ...                   ...            ...                  ...          ...
# 99995               1230A             YW                 <NA>         2016
# 99996                None             WH                 <NA>         2021
# 99997                None             GY                 <NA>         2020
# 99998                None             BK                 <NA>         2002
# 99999                None             WH                 <NA>         2020
#
#       meter_number feet_from_curb no_standing_or_stopping_violation  \
# 0             None              0                              None
# 1             None              0                              None
# 2             None              0                              None
# 3             None              0                              None
# 4             None              0                              None
# ...            ...            ...                               ...
# 99995         None              0                              None
# 99996         None              0                              None
# 99997         None              0                              None
# 99998         None              0                              None
# 99999         None              0                              None
#
#       hydrant_violation  double_parking_violation
# 0                  None                      None
# 1                  None                      None
# 2                  None                      None
# 3                  None                      None
# 4                  None                      None
# ...                 ...                       ...
# 99995              None                      None
# 99996              None                      None
# 99997              None                      None
# 99998              None                      None
# 99999              None                      None
#
# [100000 rows x 34 columns]

# %%
sql_query_import_1 = '''
CREATE OR REPLACE TABLE parking_violation_codes AS
SELECT *
FROM read_csv_auto(
  'data/dof_parking_violation_codes.csv',
  normalize_names=TRUE
)
'''

sql_query_import_2 = '''
CREATE OR REPLACE TABLE parking_violations_2023 AS
SELECT *
FROM read_csv_auto(
  'data/parking_violations_issued_fiscal_year_2023_sample.csv',
  normalize_names=TRUE
)
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
  con.sql(sql_query_import_1)
  con.sql(sql_query_import_2)
